# %%
import pandas as pd

# %%
# Load the generated synthetic Conjunction Data Messages (CDMs)
df = pd.read_csv('../datasets/synthetic_cdms.csv')
df.head()

# %%
# Check for missing values and verify data types
df.info()

# %%
# Display the statistical distribution of the dataset
# Notice the minimum, maximum, and mean values for miss_distance_km
df.describe()
